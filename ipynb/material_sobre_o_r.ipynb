# %% [markdown]
# ## Material sobre R (em português)

# %% [markdown]
# Nesta página estão reunidos alguns tutoriais sobre o R em português nos quais o usuário poderá obter conhecimentos básicos do R, já que neste site presume-se que o usuário já os possua.
#
# Os documentos até o momento reunidos estão listados a seguir:
#
# ---
#
# 38 - **_Estatística Experimental com o uso software R_** - Silvano Cesar da Costa ( [pdf](http://www.uel.br/pessoal/silvano/Ciencia_Animal/Apostila/Livro.pdf) )
#
# ---
#
# 37 - **_Computação em R - Análise Experimental_** - Eric Bastos Gorgens ( [site](https://leanpub.com/comprexperimental) )
#
# ---
#
# 36 - **_Computação em R - Introdução_** - Eric Bastos Gorgens ( [site](https://leanpub.com/comprintroducao) )
#
# ---
#
# 35 - **_Análise Exploratória de Dados usando o R_** - Enio Jelihovschi ( [pdf](http://www.uesc.br/editora/livrosdigitais2/analiseexploratoria_r.pdf) )
#
# ---
#
# 34 - Roteiro de aula do curso: **_Computação: introdução a aplicativos de informática para auxílio à pesquisa_** - FIOCRUZ IPEC ( [pdf](http://blog.ipec.fiocruz.br/lapclin-chagas/wp-content/uploads/sites/2/2014/02/Roteiro_R2014.pdf) )
#
# ---
#
# 33 - **_Desvendando a Estatística com o R Commander_** - Jonas Joacir Radtke ( [pdf](http://paginapessoal.utfpr.edu.br/jonas/disciplinas/estatistica-experimental/material-de-apoio/desvendando_a_estatistica_com_o_r_commander.pdf) )
#
# ---
#
# 32 -  **_Curso de R_** - Fernando Amaral ( [pdf](http://www.datascientist.com.br/Artigos/CURSOR.pdf) )
#
# ---
#
# 31 - **_Análise de dados biológicos com a linguagem R_** - Alberto G. Murta ( [pdf](http://albertomurta.wikispaces.com/file/view/ApontamentosPEAD.pdf) )
#
# ---
#
# 30 - **_Introdução ao R Commander_** - Umberto Guarnier Mignozzetti ( [pdf](http://www.nadd.prp.usp.br/cis/arqs/aprcmdr.pdf) )
#
# ---
#
# 29 - **_Introdução ao Software Estatístico R_** - Profa. Denise Beatriz Ferrari ( [pdf](http://www.mec.ita.br/~denise/tutorials/IntroR.pdf) )
#
# ---
#
# 28 - **_Usando o R para Avaliação Estatística de Experimentos_** – versão 0.3 - Leandro Silva Galvão de Carvalho ( [pdf](http://www.dcc.ufam.edu.br/leandro/images/stories/Usando_R_v0.3.pdf) )
#
# ---
#
# 27 - **_Introdução ao uso do programa R_** - Victor Lemes Landeiro ( [pdf](http://amazonpire.org/documents/Introducao_ao_R.pdf) )
#
# ---
#
# 26 - Apostila do Curso de Extensão: Software Estatístico Livre R -  Marcelo Rubens dos Santos do Amaral, Carolina de Vasconcelos Cesário, Guilherme de Almeida Gonçalves, Luciano Teixeira Schultz, Kauê Pinheiro Veras da Cunha, Thiago dos Santos Souza ( [pdf](http://www.ime.uerj.br/~mrubens/slae/Texto_SLAE2.pdf) )
#
# ---
#
# 25 - **_Estatística aplicada à ecologia usando o R_** - Diogo Borges Provete, Fernando Rodrigues da Silva e Thiago Gonçalves Souza ( [pdf](http://cran.r-project.org/doc/contrib/Provete-Estatistica_aplicada.pdf) )
#
# ---
#
# 24 - **_RECURSO COMPUTACIONAL PARA ESTATÍSTICA - Uma breve introdução ao R Básico com RStudio_** - Prof. Edson Antonio Alves da Silva ( [pdf](https://docs.google.com/viewer?a=v&pid=sites&srcid=ZGVmYXVsdGRvbWFpbnxlZHNvbnVuaW9lc3RlfGd4OjdmMDk2NmIyNzYzNTdmZDU) )
#
# ---
#
# 23 - **_Estatística Básica e Experimentação no R_** - Walmes Marques Zeviani ( [pdf](http://www.leg.ufpr.br/~walmes/cursoR/cursoR2.pdf) )
#
# ---
#
# 22 - **_CONTROLE ESTATÍSTICO DE PROCESSOS COM O R_** - Elisa Henning e Vilson Vieira da Silva Junior ( [pdf](http://www.qualimetria.ufsc.br/site/arquivos/4393_TUTORIAL.pdf) )
#
# ---
#
# 21 - **_Introdução à Estatística  Básica com R_** - Eric Batista Ferreira e Marcelo Silva de Oliveira ( [pdf](http://www.quintiliano.prof.ufu.br/index_arquivos/EBR.pdf) )
#
# ---
#
# 20 - Artigo: **_UMA BR
# EVE VISÃO SOBRE APLICAÇÕES EM AMBIENTE R PARA O ENSINO DE ENGENHARIA_** Elisa Henning, Custodio da Cunha Alves, Andréa Cristina Konrath, Robert Wayne Samohyl ( [pdf](http://dspace.universia.net/bitstream/2024/555/1/ArtigoCobenge-1.pdf) )
#
# ---
#
# 19 - **_GNU/R - uma breve introdução_** - Bruno Lopes ( [pdf](http://epge.fgv.br/we/Sistema_R?action=AttachFile&do=get&target=gnu-r.pdf) )
#
# ---
#
# 18 - **_Minicurso de Estatística Básica: Introdução ao Software R_** - Programa de Educação Tutorial Eng Elétrica Universidade Federal de Santa Maria ( [pdf](http://petee01.ctlab.ufsm.br/petee/sites/default/files/Curso%20de%20R%20-%20Apostila%20PET-EE.pdf) )
#
# ---
#
# 17 - **_Análise Gráfica com Uso do R_** - Adilson do Anjos ( [pdf](https://sites.google.com/site/marcosfs2006/material_r/analise_grafica.pdf?attredirects=0) )
#
# ---
#
# 16 - Conjunto de tutoriais de Luiz Alexandre Peternelli ( [html](http://www.dpi.ufv.br/~peternelli/tutoriaisR/index.htm) )
#
# ---
#
# 15 - **_R para cientistas sociais_** - Jackson Aquino ( [pdf](http://www.uesc.br/editora/livrosdigitais_20140513/r_cientistas.pdf) )
#
# ---
#
# 14 - **_Estatística com R: Uma iniciação para o Ensino Básico e Secundário_** ( [pdf](http://alea.ine.pt/Html/statofic/html/dossier/doc/dossie14.pdf) )
#
# ---
#
# 13 - Lista de discussão onde é possível postar as dúvidas.  A lista chama-se [R-br](http://listas.inf.ufpr.br/cgi-bin/mailman/listinfo/r-br) e é sucessora da R_STAT.
#
# ---
#
# 12 - **_Recursos Computacionais Utilizando o R_** - Prof. Daniel Furtado Ferreira ( [pdf](http://www.dex.ufla.br/~danielff/meusarquivospdf/RRC0.pdf) )
#
# ---
#
# 11 - **_Estatística Computacional Utilizando R_** - Prof. Daniel Furtado Ferreira ( [pdf](http://www.dex.ufla.br/~danielff/meusarquivospdf/apeco.pdf) )
#
# ---
#
# 10 - Livro: **_Conhecendo o R - Uma visão mais que estatística_** ( [html](http://www.editoraufv.com.br/detalhes.asp?idproduto=1593809) )
#
# ---
#
# 9 - **_Estatística Básica Usando o R_** - Apostila do Prof. Augusto Filho ( [pdf](http://br.geocities.com/augustofilho/estatistica.pdf) )
#
# ---
#
# 8 - **_Introdução ao Ambiente Computacional R_** - Tutorial de autoria de Paula da Silva Carvalho e Maria da Conceição F. Freitas Tandel. ( [pdf](http://www.rc.unesp.br/conceicao/R/tutoport-apostilaR_monitoria.PDF) )
#
# ---
#
# 7 - **_R - Introdução à Programação e Aplicações_** - apostila do prof. Joaquim Pereira Neto  ( [doc](https://sites.google.com/site/marcosfs2006/APOSTILA_ORIGINAL_R.doc?attredirects=0) ).
# A apostila e o código utilizado no texto e estão compactados no arquivo [CursoR.zip](https://sites.google.com/site/marcosfs2006/CursoR.zip?attredirects=0)
#
# ---
#
# 6 - **_Aprendendo R_** - Tutorial da ENSP/FIOCRUZ  de Antonio Guilherme Fonseca Pacheco, Geraldo Marcelo da Cunha e Valeska Lima Andreozzi ( [pdf](https://sites.google.com/site/marcosfs2006/Rbasico2005.pdf?attredirects=0) ).
#
# ---
#
# 5 - No site http://www.estatisticanor.xpg.com.br está em elaboração uma apostila denominada "Ferramentas Estatísticas Básicas da Qualidade - guia prático do R". Até o momento (25.11.2008) já estavam prontos oito capítulos. [Cap1](http://www.estatisticanor.xpg.com.br/apostila/cap1.pdf), [Cap2](http://www.estatisticanor.xpg.com.br/apostila/cap2.pdf), [Cap3](http://www.estatisticanor.xpg.com.br/apostila/cap3.pdf), [Cap4](http://www.estatisticanor.xpg.com.br/apostila/cap4.pdf), [Cap5](http://www.estatisticanor.xpg.com.br/apostila/cap5.pdf), [Cap6](http://www.estatisticanor.xpg.com.br/apostila/cap6.pdf), [Cap7](http://www.estatisticanor.xpg.com.br/apostila/cap7.pdf), [Cap8](http://www.estatisticanor.xpg.com.br/apostila/cap8.pdf)
#
# ---
#
# 4 - No CRAN (Compreensive R Archive Network) estão disponíveis para download
# cinco tutoriais em português:
#
# * **_Introdução à Programação em R_** - Luiz Torgo ( [pdf](http://cran-r.c3sl.ufpr.br/doc/contrib/Torgo-ProgrammingIntro.pdf) )
# * **_Bioestatística usando R_** - Colin Robert Beasley ( [pdf](http://cran-r.c3sl.ufpr.br/doc/contrib/Beasley-BioestatisticaUsandoR.pdf) )
# * **_Introdução à Biometria utilizando R_** - Leandro R. Monteiro and José Louvise Gomes-Jr ( [pdf]() )
# * **_Tópicos de Estatística utilizando R_** - Fernando Itano ( [pdf](http://cran.r-project.org/doc/contrib/Itano-descriptive-stats.pdf) )
# * **_Guia de instalação do R_** - Fernando Itano ( [pdf](http://cran.r-project.org/doc/contrib/Itano-installation.pdf) )
#
# ---
#
# 3 - A página do Fernando Henrique Ferraz Pereira da Rosa também disponibiliza alguns materiais:
#
# * **_Aprenda a usar o R_** - Tutorial on line ( [html](http://www.feferraz.net/br/rlearn.html) )
# * [Materiais Diversos](http://www.feferraz.net/br/rmain.html)
#
# ---
#
# 2 - A página do Prof. Paulo Justiniano Ribeiro Jr. da UFPR disponibiliza alguns materiais:
#
# * **_Introdução ao Ambiente Estatístico R_** ( [html](http://leg.ufpr.br/~paulojus/embrapa/Rembrapa/) )
# * **_Curso de Extensão em R_** ( [pdf](http://leg.ufpr.br/cursoR/cursoR.pdf) )
# * **_Introdução ao Sistema Estatístico R_** - Minicurso ministrado na EMBRAPA ( [pdf](http://leg.ufpr.br/~paulojus/embrapa/Rembrapa/Rembrapa.pdf) )
# * Material do Minicurso ministrado na ESALQ ( [pdf](http://leg.ufpr.br/Rpira/Rpira.pdf) )
#
# ---
#
# 1 - Tradução do manual **_An Introduction to R_** referente à versão 1.1.0 do R datada de 11.07.2000 ( [zip](https://sites.google.com/site/marcosfs2006/R-langtraduzido.zip?attredirects=0) )

# %% [markdown]
# **Marcos F Silva**
